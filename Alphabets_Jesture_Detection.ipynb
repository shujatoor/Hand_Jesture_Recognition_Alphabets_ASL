# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2
import time
import csv
import os
import mediapipe as mp
from keras.models import load_model
import numpy as np
#import gtts
#from playsound import playsound
#from function_sound_file import function_sound

# %%
#load model
model_path = 'alpha_classifier.hdf5'
model = tf.keras.models.load_model(model_path)

# %%
def get_className(classNo):
    if classNo==1:
        return "A"
    elif classNo==2:
        return "B"
    elif classNo==3:
        return "C"
    elif classNo==4:
        return "D"
    elif classNo==5:
        return "E"
    elif classNo==6:
        return "F"
    elif classNo==7:
        return "G"
    elif classNo==8:
        return "H"
    elif classNo==9:
        return "I"
    elif classNo==10:
        return "J"
    elif classNo==11:
        return "K"
    elif classNo==12:
        return "L"
    elif classNo==13:
        return "M"
    elif classNo==14:
        return "N"
    elif classNo==15:
        return "O"
    elif classNo==16:
        return "P"
    elif classNo==17:
        return "Q"
    elif classNo==18:
        return "R"
    elif classNo==19:
        return "S"
    elif classNo==20:
        return "T"
    elif classNo==21:
        return "U"
    elif classNo==22:
        return "V"
    elif classNo==23:
        return "W"
    elif classNo==24:
        return "X"
    elif classNo==25:
        return "Y"
    elif classNo==26:
        return "Z"

# %%
class handDetector():
    def __init__(self, mode = False, maxHands = 1, modelComplexity=1, detectionCon = 0.5, trackCon = 0.5):
        self.mode = mode
        self.maxHands = maxHands
        self.modelComplex = modelComplexity
        self.detectionCon = detectionCon
        self.trackCon = trackCon

        self.mpHands = mp.solutions.hands
        self.hands = self.mpHands.Hands(self.mode, self.maxHands, self.modelComplex, self.detectionCon, self.trackCon)
        self.mpDraw = mp.solutions.drawing_utils
        
    def findHands(self,img, draw = True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.hands.process(imgRGB)
        # print(results.multi_hand_landmarks)

        if self.results.multi_hand_landmarks:
            for handLms in self.results.multi_hand_landmarks:
                if draw:
                    self.mpDraw.draw_landmarks(img, handLms, self.mpHands.HAND_CONNECTIONS)
        return img

    def findPosition(self, img, draw = True):
        lmdict = {}
        lmlist = []
        if self.results.multi_hand_landmarks:
            for hand_no, hand_landmarks in enumerate(self.results.multi_hand_landmarks):  
                for id, lm in enumerate(hand_landmarks.landmark):
                    h, w, c = img.shape
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    lmlist.append([id, lm.x, lm.y])
                    if draw:
                        cv2.circle(img, (cx, cy), 3, (255, 0, 255), cv2.FILLED)
            lmdict[hand_no] = lmlist
        return lmdict

# %%
def main():
    pTime = 0
    cTime = 0
    cap = cv2.VideoCapture(0)
    font=cv2.FONT_HERSHEY_COMPLEX
    detector = handDetector()
    pos = []
    temp = []
    #sound_file = 'sound.mp3'
    while True:
        success, img = cap.read()
        img = detector.findHands(img)
        lmdict = detector.findPosition(img)
        if len(lmdict) != 0:
            for key, value in lmdict.items():
                #print(f'Hand Number {key}', ' : ', value[0][1])
                for i in range(len(value)):
                    for j in range(2):
                        temp.append(value[i][j+1])
                    if len(temp)== 42:
                        predict_result = model.predict(np.array([temp]))
                        #print(predict_result)
                        #print(np.argwhere(predict_result>0.9))
                        class_index = np.argmax(np.squeeze(predict_result))
                        #probabilityValue=np.amax(predict_result)
                        if class_index==1:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
                            #tts = gtts.gTTS(str(get_className(class_index)))
                            #tts.save(sound_file)
                            #function_sound(sound_file)
                            #os.remove(sound_file)
                            #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==2:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
                            #tts = gtts.gTTS(str(get_className(class_index)))
                            #tts.save(sound_file)
                            #function_sound(sound_file)
                            #os.remove(sound_file)
                            #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==3:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
                            #tts = gtts.gTTS(str(get_className(class_index)))
                            #tts.save(sound_file)
                            #function_sound(sound_file)
                            #os.remove(sound_file)
                            #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==4:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
                            #tts = gtts.gTTS(str(get_className(class_index)))
                            #tts.save(sound_file)
                            #function_sound(sound_file)
                            #os.remove(sound_file)
                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==5:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
                            #tts = gtts.gTTS(str(get_className(class_index)))
                            #tts.save(sound_file)
                            #playsound(sound_file)
                            #os.remove(sound_file)
                            #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==6:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==7:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==8:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==9:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==10:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==11:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==12:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==13:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==14:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==15:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==16:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==17:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==18:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==19:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==20:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==21:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==22:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==23:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==24:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        
                        elif class_index==25:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)

                        elif class_index==26:
                            cv2.putText(img, str(get_className(class_index)), (70, 140), font, 3, (255, 0, 0), 3)
#                             #cv2.putText(img,str(round(probabilityValue*100, 2))+"%" ,(180, 75), font, 0.75, (255,0,0),2, cv2.LINE_AA)
                        temp = []
                        
                    else:
                        pass
                        
        
        cTime = time.time()
        fps = 1 / (cTime - pTime)
        pTime = cTime

        #cv2.putText(img, str(int(fps)), (10, 70), cv2.FONT_HERSHEY_PLAIN, 2, (255, 0, 255), 3)

        cv2.imshow("Image", img)
        cv2.waitKey(1)
        if cv2.waitKey(1) & 0xFF == ord('c'):
            break
            
    #pos = list(map(list,zip(*[iter(pos)]*42))) #convert the list 'pos' to list of lists 
 
    #for i in range(len(pos)):
        #pos[i].insert(0,2)
        
    #path = 'test.csv'
    #with open(path, 'w', newline='') as file:
        #csv_writer = csv.writer(file)
        #csv_writer.writerows(pos)
    cap.release()
    cv2.destroyAllWindows()

# %%
if __name__ == "__main__":
    main()
